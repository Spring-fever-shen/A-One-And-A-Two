# %%
#导入库
import pandas as pd
import numpy as np
#让 DataFrame 显示所有列
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 查看数据编码

# %%
import chardet
#导入库，这是一个专门用于检测文件编码的工具，能自动分析文件内容并判断其编码格式。
def check_encoding(filename):
    rawdata = open(filename, 'rb').read()
    result = chardet.detect(rawdata)
    encoding = result['encoding']
    #从结果字典中提取编码格式
    confidence = result['confidence']
    #从结果字典中提取可信度
    return encoding, confidence

file_path = '000001.csv'# 添加文件路径
encoding, confidence = check_encoding(file_path)
print(f"Encoding: {encoding}, Confidence: {confidence}")
# Out:
# Encoding: ascii, Confidence: 1.0

# %%
from IPython.core.interactiveshell import InteractiveShell  
InteractiveShell.ast_node_interactivity = 'all'
#默认情况下，下一个代码单元格里只有最后一行代码print(date)的结果会显示出来。
#设置为 'all' 后，单元格里所有行代码的结果都会显示

# %%
data =pd.read_csv('000001.csv')# 这是导入CSV文件的命令
data #以DataFrame 表格形式展示
print(data)
# Out:
#              Day  Preclose      Open   Highest    Lowest     Close
# 0     1990/12/19              96.050    99.980    95.790    99.980
# 1     1990/12/20     99.98   104.300   104.390    99.980   104.390
# 2     1990/12/21    104.39   109.070   109.130   103.730   109.130
# 3     1990/12/24    109.13   113.570   114.550   109.130   114.550
# 4     1990/12/25    114.55   120.090   120.250   114.550   120.250
# ...          ...       ...       ...       ...       ...       ...
# 8468   2025/8/25  3825.759  3848.163  3883.562  3839.972  3883.562
# 8469   2025/8/26  3883.562  3871.471  3888.599  3859.758  3868.382
# 8470   2025/8/27  3868.382  3869.612  3887.198  3800.350  3800.350
# 8471   2025/8/28   3800.35  3796.711  3845.087  3761.422  3843.597
# 8472   2025/8/29  3843.597  3842.823  3867.606  3839.206  3857.927
#
# [8473 rows x 6 columns]
#              Day  Preclose      Open   Highest    Lowest     Close
# 0     1990/12/19              96.050    99.980    95.790    99.980
# ...

# %% [markdown]
# ### 了解变量格式

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data.columns)
#返回的是pandas特有的Index对象，明确告诉你这是一个索引对象
print(data.columns.values)
#返回的是 NumPy数组，这将列索引对象转换成了底层的数组格式
# Out:
# Index(['Day', 'Preclose', 'Open', 'Highest', 'Lowest', 'Close'], dtype='object')
# ['Day' 'Preclose' 'Open' 'Highest' 'Lowest' 'Close']

# %% [markdown]
# ## 时间序列数据的格式 Time-Series Data 以及 数据框 Dataframe的基本知识

# %% [markdown]
# #### 选择某一列

# %%
data['Day']
# Out:
# 0       1990/12/19
# 1       1990/12/20
# 2       1990/12/21
# 3       1990/12/24
# 4       1990/12/25
#            ...
# 8468     2025/8/25
# 8469     2025/8/26
# 8470     2025/8/27
# 8471     2025/8/28
# 8472     2025/8/29
# Name: Day, Length: 8473, dtype: object

# %%
data.Day
# Out:
# 0       1990/12/19
# 1       1990/12/20
# 2       1990/12/21
# 3       1990/12/24
# 4       1990/12/25
#            ...
# 8468     2025/8/25
# 8469     2025/8/26
# 8470     2025/8/27
# 8471     2025/8/28
# 8472     2025/8/29
# Name: Day, Length: 8473, dtype: object

# %%
data[['Day']]
# Out:
#              Day
# 0     1990/12/19
# 1     1990/12/20
# 2     1990/12/21
# 3     1990/12/24
# 4     1990/12/25
# ...          ...
# 8468   2025/8/25
# 8469   2025/8/26
# 8470   2025/8/27
# 8471   2025/8/28
# 8472   2025/8/29
#
# [8473 rows x 1 columns]

# %%
#注意两行代码的区别
type(data['Day'])
type(data[['Day']])
# Out:
# pandas.core.series.Series
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 如何选择多列

# %%
data[['Day','Close']]
# Out:
#              Day     Close
# 0     1990/12/19    99.980
# 1     1990/12/20   104.390
# 2     1990/12/21   109.130
# 3     1990/12/24   114.550
# 4     1990/12/25   120.250
# ...          ...       ...
# 8468   2025/8/25  3883.562
# 8469   2025/8/26  3868.382
# 8470   2025/8/27  3800.350
# 8471   2025/8/28  3843.597
# 8472   2025/8/29  3857.927
#
# [8473 rows x 2 columns]

# %% [markdown]
# ### 如何选择行

# %%
data[0:7]
# 该代码用于切片选取data数据框中的第0行到第6行（共7行）
# Out:
#           Day  Preclose    Open  Highest  Lowest   Close
# 0  1990/12/19             96.05    99.98   95.79   99.98
# 1  1990/12/20     99.98  104.30   104.39   99.98  104.39
# 2  1990/12/21    104.39  109.07   109.13  103.73  109.13
# 3  1990/12/24    109.13  113.57   114.55  109.13  114.55
# 4  1990/12/25    114.55  120.09   120.25  114.55  120.25
# 5  1990/12/26    120.25  125.27   125.27  120.25  125.27
# 6  1990/12/27    125.27  125.27   125.28  125.27  125.28

# %%
data.iloc[0:5,0:6] 
# 该代码使用 iloc 按照行号和列号进行数据选择
# data.iloc[0:5, 0:6]表示选取data数据框的第0行到第4行和第0列到第5列的数据
# Out:
#           Day  Preclose    Open  Highest  Lowest   Close
# 0  1990/12/19             96.05    99.98   95.79   99.98
# 1  1990/12/20     99.98  104.30   104.39   99.98  104.39
# 2  1990/12/21    104.39  109.07   109.13  103.73  109.13
# 3  1990/12/24    109.13  113.57   114.55  109.13  114.55
# 4  1990/12/25    114.55  120.09   120.25  114.55  120.25

# %%
data.at[2,'Close']
#at 是pandas提供的高效访问单个元素的属性，专门用于按「行标签 + 列名」定位。
# Out:
# 109.13

# %%
data[data['Day'] == "1990/12/21"].Close
# data[data['Day'] == "1990/12/21"] 先筛选出日期为"1990/12/21"的行
# .Open是从筛选后的 DataFrame 中提取 Close 列的数据
# Out:
# 2    109.13
# Name: Close, dtype: float64

# %% [markdown]
# ### 按照时间

# %%
data['Day'] = pd.to_datetime(data['Day'],format = '%Y/%m/%d')
data
# 将'Day'列从字符串格式转换为日期时间格式
# 将 DataFrame 中 Day 列的文本格式日期转换为 pandas 的 datetime 类型
# format='%Y/%m/%d' 指定了输入日期的格式：年/月/日
# 其中%Y、%m 等格式符的大小写也有区别，大写 Y 表示 4 位年份（如 2023）；小写 %y 表示 2 位年份
# Out:
#             Day  Preclose      Open   Highest    Lowest     Close
# 0    1990-12-19              96.050    99.980    95.790    99.980
# 1    1990-12-20     99.98   104.300   104.390    99.980   104.390
# 2    1990-12-21    104.39   109.070   109.130   103.730   109.130
# 3    1990-12-24    109.13   113.570   114.550   109.130   114.550
# 4    1990-12-25    114.55   120.090   120.250   114.550   120.250
# ...         ...       ...       ...       ...       ...       ...
# 8468 2025-08-25  3825.759  3848.163  3883.562  3839.972  3883.562
# 8469 2025-08-26  3883.562  3871.471  3888.599  3859.758  3868.382
# 8470 2025-08-27  3868.382  3869.612  3887.198  3800.350  3800.350
# 8471 2025-08-28   3800.35  3796.711  3845.087  3761.422  3843.597
# 8472 2025-08-29  3843.597  3842.823  3867.606  3839.206  3857.927
#
# [8473 rows x 6 columns]

# %%
data = data.sort_values(by=['Day'], axis=0, ascending=False)
data
# 按照 Day 列对 DataFrame 进行排序
# ascending=False：设置排序方向为降序（从大到小）如果设为True，则是升序
# Out:
#             Day  Preclose      Open   Highest    Lowest     Close
# 8472 2025-08-29  3843.597  3842.823  3867.606  3839.206  3857.927
# 8471 2025-08-28   3800.35  3796.711  3845.087  3761.422  3843.597
# 8470 2025-08-27  3868.382  3869.612  3887.198  3800.350  3800.350
# 8469 2025-08-26  3883.562  3871.471  3888.599  3859.758  3868.382
# 8468 2025-08-25  3825.759  3848.163  3883.562  3839.972  3883.562
# ...         ...       ...       ...       ...       ...       ...
# 4    1990-12-25    114.55   120.090   120.250   114.550   120.250
# 3    1990-12-24    109.13   113.570   114.550   109.130   114.550
# 2    1990-12-21    104.39   109.070   109.130   103.730   109.130
# 1    1990-12-20     99.98   104.300   104.390    99.980   104.390
# 0    1990-12-19              96.050    99.980    95.790    99.980
#
# [8473 rows x 6 columns]

# %%
help(data.sort_values)
# 使用help()函数查看sort_values方法的详细帮助信息
# help()函数可以显示任何Python对象、函数或方法的文档字符串
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(by: 'IndexLabel', *, axis: 'Axis' = 0, ascending: 'bool | list[bool] | tuple[bool, ...]' = True, inplace: 'bool' = False, kind: 'SortKind' = 'quicksort', na_position: 'str' = 'last', ignore_index: 'bool' = False, key: 'ValueKeyFunc | None' = None) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Sort by the values along either axis.
#
#     Parameters
#     ----------
#     by : str or list of str
#         Name or list of names to sort by.
#
#         - if `axis` is 0 or `'index'` then `by` may contain index
#           levels and/or column labels.
#         - if `axis` is 1 or `'columns'` then `by` may contain column
#           levels and/or index labels.
#     axis : "{0 or 'index', 1 or 'columns'}", default 0
#          Axis to be sorted.
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
# ...

# %%
data = data.sort_values(by=['Day'],ascending=True)
data
# Out:
#             Day  Preclose      Open   Highest    Lowest     Close
# 0    1990-12-19              96.050    99.980    95.790    99.980
# 1    1990-12-20     99.98   104.300   104.390    99.980   104.390
# 2    1990-12-21    104.39   109.070   109.130   103.730   109.130
# 3    1990-12-24    109.13   113.570   114.550   109.130   114.550
# 4    1990-12-25    114.55   120.090   120.250   114.550   120.250
# ...         ...       ...       ...       ...       ...       ...
# 8468 2025-08-25  3825.759  3848.163  3883.562  3839.972  3883.562
# 8469 2025-08-26  3883.562  3871.471  3888.599  3859.758  3868.382
# 8470 2025-08-27  3868.382  3869.612  3887.198  3800.350  3800.350
# 8471 2025-08-28   3800.35  3796.711  3845.087  3761.422  3843.597
# 8472 2025-08-29  3843.597  3842.823  3867.606  3839.206  3857.927
#
# [8473 rows x 6 columns]

# %% [markdown]
# #### data.set_index('Day', inplace = True)
# #### 将 'Day' 列从普通数据列转换为行索引（index）。设置后，'Day' 列会从原数据列中移除，成为每行的标识标签。
# #### 本人电脑在运行完这一步后，第一列数字消失，第一行中的'Day'会下移，之后此前所有的代码都会报错（"None of ['Day'] are in the columns"，详细见C1）原因不明

# %%
data['1995-12':'2000-04']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data['1995-12':'2000-04']
#       2 #此前以降将 DataFrame 中 Day 列的文本格式日期转换为 pandas 的 datetime 类型
#
# NameError: name 'data' is not defined
